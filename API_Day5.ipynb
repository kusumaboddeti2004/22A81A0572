# %% [markdown]
# <a href="https://colab.research.google.com/github/kusumaboddeti2004/22A81A0572/blob/main/API_Day5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Random Fox API

# %%
import requests

# %%
page=requests.get('https://randomfox.ca/floof')

# %%
print(page.status_code)
# Out:
# 200

# %%
print(page.text)
# Out:
# {"image":"https:\/\/randomfox.ca\/images\/3.jpg","link":"https:\/\/randomfox.ca\/?i=3"}

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',   #accept=will decide format of the output
  'X-CMC_PRO_API_KEY': '17ce6a23-722e-4b64-87e1-52a6e8d7642f',
  }

session = Session()   #session=request to access API
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
   print(e)
# Out:
# {'status': {'timestamp': '2024-02-16T09:48:31.893Z', 'error_code': 0, 'error_message': None, 'elapsed': 1, 'credit_count': 1, 'notice': None}, 'data': [{'id': 130, 'name': 'zgwutccr2ke', 'symbol': '5uy5pu5i2z9', 'slug': 'dqffglmalri', 'cmc_rank': 2422, 'num_market_pairs': 5089, 'circulating_supply': 3488, 'total_supply': 8463, 'max_supply': 4210, 'infinite_supply': None, 'last_updated': '2024-02-16T09:48:31.893Z', 'date_added': '2024-02-16T09:48:31.893Z', 'tags': ['jhakcg7p25l', 'ntchgq02lde', '8upcvr3yhta', '9w81v6ohmwe', 'ims8244xrab', '9zj9ceetoai', '0ddahqyv2aot', '01xvahpfb2ms', '54r0oo7ev3v', 'n2rp9c59ce'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.25115880378785116, 'volume_24h': 2490, 'volume_change_24h': 0.0058410756911599915, 'percent_change_1h': 0.6053784658312749, 'percent_change_24h': 0.9829906672854531, 'percent_change_7d': 0.3344388253802566, 'market_cap': 0.07007130970470743, 'market_cap_
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
norm=pd.json_normalize(data['data'])
norm
# Out:
#      id         name       symbol         slug  cmc_rank  num_market_pairs  \
# 0   130  zgwutccr2ke  5uy5pu5i2z9  dqffglmalri      2422              5089
# 1  8798  3q5zvgjif4v  clgbr3bh2k8  jew7cn3bs1f      9177               974
# 2  2242  yrus0rd38zs  yeyk9ojbebb   l0nzk3ih6k      1193              9363
# 3  3803  e77mpxtlm0v   g1i7g7a0ct  1ogpszj7x9r      6691               163
# 4  8822  922ua9vh6f5  xu7fjt6d3ld  q8a1or4bsmm      2411              7917
# 5  8752  ytdcrd5ervn   i8u61apx4r  ybji4m37jet      1437              2571
# 6  2226  5il5b58lldx  r83om7scll9   sl96brqvpf      2314              7179
# 7   941  vdqjtvt81mj   qv1j8wwo9d  65p249wmfyd      6954              3133
# 8  4610  phmcxpnk0ch  8fs9g83ml7l  ej2grq047fn      7135              2916
# 9  9330  4mi96wcrxor  xlqhxiscewh   lzdln67xfm      1332              3334
#
#    circulating_supply  total_supply  max_supply infinite_supply  ...  \
# 0                3488          8463        4210            None  ...
# ...
